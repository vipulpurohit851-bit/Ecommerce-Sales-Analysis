# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b9a31f6-78ba-4888-9277-b07b15bbe98e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b9a31f6-78ba-4888-9277-b07b15bbe98e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd


GeoLocation_New = pd.read_csv("GeoLocation_New.csv")

# %%
import pandas as pd

Order_Payments_New = pd.read_csv("Order_Payments_New.csv")

# %%
import pandas as pd

Sellers_New = pd.read_csv("Sellers_New.csv")

# %%
import pandas as pd

Order_Reviews_New = pd.read_csv("Order_Reviews_New.csv")
Order_Payments_New = pd.read_csv("Order_Payments_New.csv")
Product_New = pd.read_csv("Product_New.csv")
Order_Item_New = pd.read_csv("Order_Item_New.csv")
Orders_New = pd.read_csv("Orders_New.csv")
Customers_New = pd.read_csv("Customers_New.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_182/4221977765.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 Order_Reviews_New = pd.read_csv("Order_Reviews_New.csv")
#       4 Order_Payments_New = pd.read_csv("Order_Payments_New.csv")
#       5 Product_New = pd.read_csv("Product_New.csv")
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'Order_Reviews_New.csv',
#  'GeoLocation_New.csv',
#  'Customers_New.csv',
#  'Orders_New.csv',
#  'Order_Payments_New.csv',
#  'Product_New.csv',
#  'Sellers_New.csv',
#  'Order_Item_New.csv',
#  'sample_data']

# %%
Order_Reviews_New.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_creation_date review_answer_timestamp  \
# 0             4           2018-01-18     2018-01-18 21:46:00
# 1             5           2018-03-10     2018-03-11 03:05:00
# 2             5           2018-02-17     2018-02-18 14:36:00
# 3             5           2017-04-21     2017-04-21 22:02:00
# 4             5           2018-03-01     2018-03-02 10:26:00
#
#    response_time_hours
# 0                21.77
# 1                27.08
# 2                38.60
# 3                22.03
# 4                34.43

# %%
Order_Payments_New.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
Sellers_New.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
GeoLocation_New.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
Product_New.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
Order_Item_New.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0      9/19/2017 9:45   58.90          13.29
# 1      5/3/2017 11:05  239.90          19.93
# 2     1/18/2018 14:48  199.00          17.87
# 3     8/15/2018 10:10   12.99          12.79
# ...

# %%
Orders_New.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered          10/2/2017 10:56   10/2/2017 11:07
# 1    delivered          7/24/2018 20:41    7/26/2018 3:24
# 2    delivered            8/8/2018 8:38     8/8/2018 8:55
# 3    delivered         11/18/2017 19:28  11/18/2017 19:45
# 4    delivered          2/13/2018 21:18   2/13/2018 22:20
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0              10/4/2017 19:55              10/10/2017 21:25
# 1              7/26/2018 14:31                8/7/2018 15:27
# ...

# %%
Customers_New.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
Order_Reviews_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
Order_Payments_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
GeoLocation_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
Sellers_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
Product_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
Order_Item_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
Product_New.head()

# %%
Orders_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
Customers_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
Order_Reviews_New.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
# i drop colum review_comment_title and review_comment_message because too much null values also don,'t require for analysis
Order_Reviews_New = Order_Reviews_New.drop(columns = ['review_comment_title','review_comment_message'])

# %%
Order_Reviews_New.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_creation_date review_answer_timestamp
# 0             4       1/18/2018 0:00         1/18/2018 21:46
# 1             5       3/10/2018 0:00          3/11/2018 3:05
# 2             5       2/17/2018 0:00         2/18/2018 14:36
# 3             5       4/21/2017 0:00         4/21/2017 22:02
# 4             5        3/1/2018 0:00          3/2/2018 10:26

# %%
Order_Reviews_New['review_creation_date'] = pd.to_datetime(Order_Reviews_New['review_creation_date'])
Order_Reviews_New['review_answer_timestamp'] = pd.to_datetime(Order_Reviews_New['review_answer_timestamp'])

# %%
Order_Reviews_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98410 entries, 0 to 99223
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                98410 non-null  object
#  1   order_id                 98410 non-null  object
#  2   review_score             98410 non-null  int64
#  3   review_creation_date     98410 non-null  datetime64[ns]
#  4   review_answer_timestamp  98410 non-null  datetime64[ns]
#  5   response_time_hours      98410 non-null  float64
# dtypes: datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 5.3+ MB

# %%
Order_Reviews_New['response_time_hours'] = (Order_Reviews_New['review_answer_timestamp'] - Order_Reviews_New['review_creation_date']).dt.total_seconds() / 3600

# %%
Order_Reviews_New.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_creation_date review_answer_timestamp  \
# 0             4           2018-01-18     2018-01-18 21:46:00
# 1             5           2018-03-10     2018-03-11 03:05:00
# 2             5           2018-02-17     2018-02-18 14:36:00
# 3             5           2017-04-21     2017-04-21 22:02:00
# 4             5           2018-03-01     2018-03-02 10:26:00
#
#    response_time_hours
# 0                21.77
# 1                27.08
# 2                38.60
# 3                22.03
# 4                34.43

# %%
Order_Reviews_New['response_time_hours'] = Order_Reviews_New['response_time_hours'].round(2)

# %%
Order_Reviews_New.info()

# %%
Order_Reviews_New['review_id'].str.len().unique()
# Out:
# array([32])

# %%
Order_Reviews_New['order_id'].str.len().unique()
# Out:
# array([32])

# %% [markdown]
#  # remove space

# %%
Order_Reviews_New['review_id'] = Order_Reviews_New['review_id'].str.strip()

# %%
Order_Reviews_New['order_id'] = Order_Reviews_New['order_id'].str.strip()

# %%
Order_Reviews_New.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # #checking duplicates in order_id and review_id

# %%
Order_Reviews_New['review_id'].duplicated().sum()
# Out:
# np.int64(814)

# %%
Order_Reviews_New['order_id'].duplicated().sum()
# Out:
# np.int64(551)

# %%
Order_Reviews_New['review_id'].nunique()
# Out:
# 98410

# %% [markdown]
# # # remove duplicates in review_id

# %%
Order_Reviews_New = Order_Reviews_New.drop_duplicates(subset=['review_id'])

# %%
Order_Reviews_New.shape
# Out:
# (98410, 6)

# %%
Order_Reviews_New['order_id'].isin(Order_Reviews_New['order_id']).sum()
# Out:
# np.int64(98410)

# %%
Order_Reviews_New.duplicated().sum()
# Out:
# np.int64(0)

# %%
Order_Reviews_New.isnull().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_creation_date       0
# review_answer_timestamp    0
# response_time_hours        0
# dtype: int64

# %%
Order_Reviews_New.to_csv("order_reviews_cleaned.csv", index=False)

# %%
from google.colab import files
files.download("order_reviews_cleaned.csv")

# %%
Orders_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
#  8   delivery_delay_days            96476 non-null  float64
#  9   delivery_days                  96476 non-null  float64
# dtypes: datetime64[ns](5), float64(2), object(3)
# memory usage: 7.6+ MB

# %%
Orders_New.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 2    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
# 3    delivered      2017-11-18 19:28:00 2017-11-18 19:45:00
# 4    delivered      2018-02-13 21:18:00 2018-02-13 22:20:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %%
Orders_New['order_purchase_timestamp'] = pd.to_datetime(Orders_New['order_purchase_timestamp'])
Orders_New['order_approved_at'] = pd.to_datetime(Orders_New['order_approved_at'])
Orders_New['order_delivered_carrier_date'] = pd.to_datetime(Orders_New['order_delivered_carrier_date'])
Orders_New['order_delivered_customer_date'] = pd.to_datetime(Orders_New['order_delivered_customer_date'])
Orders_New['order_estimated_delivery_date'] = pd.to_datetime(Orders_New['order_estimated_delivery_date'])

# %%
Orders_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
#  8   delivery_delay_days            96476 non-null  float64
#  9   delivery_days                  96476 non-null  float64
# dtypes: datetime64[ns](5), float64(2), object(3)
# memory usage: 7.6+ MB

# %%
Orders_New['order_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
Orders_New['customer_id'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
#  # Most orders are:
#
# delivered = 96,478
#
# So about 97% of orders are completed.

# %%
Orders_New['order_status'].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
delivered_orders = Orders_New[Orders_New['order_status'] == 'delivered']

# %%
Orders_New['delivery_delay_days'] = ( Orders_New['order_delivered_customer_date'] - Orders_New['order_estimated_delivery_date']).dt.days

# %%
Orders_New['order_id'].str.len().unique()
# Out:
# array([32])

# %%
Orders_New['customer_id'].str.len().unique()
# Out:
# array([32])

# %%
Orders_New['order_id'] = Orders_New['order_id'].str.strip()

# %%
Orders_New['customer_id'] = Orders_New['customer_id'].str.strip()

# %%
Orders_New['order_id'].isnull().sum()
# Out:
# np.int64(0)

# %%
Orders_New['order_estimated_delivery_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
Orders_New[Orders_New['order_delivered_customer_date'].isnull()]['order_status'].value_counts()
# Out:
# order_status
# shipped        1107
# canceled        619
# unavailable     609
# invoiced        314
# processing      301
# delivered         8
# created           5
# approved          2
# Name: count, dtype: int64

# %%
Orders_New[Orders_New['order_approved_at'].isnull()]['order_status'].value_counts()
# Out:
# order_status
# canceled     141
# delivered     14
# created        5
# Name: count, dtype: int64

# %%
delivered_orders['delivery_delay_days'].mean()
# Out:
# np.float64(-11.875888877371203)

# %%
Orders_New['delivery_days'] = (
    Orders_New['order_delivered_customer_date'] -
    Orders_New['order_purchase_timestamp']
).dt.days

# %% [markdown]
#  ## ##Average delivery time is approximately 12.09 days for delivered orders.
#  ## ##Most orders are delivered within about 12 days after purchase, indicating the typical logistics time for order fulfillment.

# %%
delivered_orders['delivery_days'].mean()
# Out:
# np.float64(12.09402923188556)

# %%
Orders_New.shape
# Out:
# (99441, 10)

# %% [markdown]
# ## ## The average delivery delay is approximately -11.88 days.
# This indicates that orders are typically delivered about 12 days earlier than the estimated delivery date.

# %%
delivered_orders['delivery_delay_days'].mean()
# Out:
# np.float64(-11.875888877371203)

# %%
Orders_New.to_csv("Orders_cleaned.csv",index = False)

# %%
from google.colab import files
files.download("Orders_cleaned.csv")

# %%
Customers_New.head(50)
# Out:
#                          customer_id                customer_unique_id  \
# 0   06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1   18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2   4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3   b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4   4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5   879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6   fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7   5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8   5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9   4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
# 10  9fb35e4ed6f0a14a4977cd9aea4042bb  2a7745e1ed516b289ed9b29c7d0539a5
# 11  5aa9e4fdd4dfd20959cad2d772509598  2a46fb94aef5cbeeb850418118cee090
# ...

# %%
Customers_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
Customers_New.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
Customers_New.duplicated().sum()
# Out:
# np.int64(0)

# %%
Customers_New['customer_unique_id'].str.len().unique()
# Out:
# array([32])

# %%
Customers_New['customer_id'] = Customers_New['customer_id'].str.strip()

# %%
Customers_New['customer_state'].duplicated().sum()
# Out:
# np.int64(99414)

# %%
Customers_New = Customers_New.drop_duplicates(subset = ['customer_id'])

# %%
Customers_New['customer_city'] = Customers_New['customer_city'].str.strip().str.lower()
Customers_New['customer_state'] = Customers_New['customer_state'].str.strip().str.upper()

# %%
customers_orders = Customers_New.groupby('customer_unique_id')['customer_id'].count().reset_index()
customers_orders.rename(columns={'customer_id': 'total_orders'},inplace=True)

# %%
customers_orders.head()
# Out:
#                  customer_unique_id  total_orders
# 0  0000366f3b9a7992bf8c76cfdf3221e2             1
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f             1
# 2  0000f46a3911fa3c0805444483337064             1
# 3  0000f6ccb0745a6a4b88665a16c9f078             1
# 4  0004aac84e0df4da2b147fca70cf8255             1

# %%
customers_orders['customer_type'] = customers_orders['total_orders'].apply(lambda x: 'repeat_customer' if x > 1 else 'single_order_customer')

# %% [markdown]
# ## ## Only about 3.12% of customers placed more than one order,
# indicating low customer retention.

# %%
customers_orders['customer_type'].value_counts(normalize=True) * 100
# Out:
# customer_type
# single_order_customer    96.881244
# repeat_customer           3.118756
# Name: proportion, dtype: float64

# %%
Customers_New.to_csv("Customers.csv",index=False)

# %%
from google.colab import files
files.download("Customers.csv")

# %%
Product_New.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
Product_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32951 non-null  object
#  2   product_name_lenght         32951 non-null  int64
#  3   product_description_lenght  32951 non-null  int64
#  4   product_photos_qty          32951 non-null  int64
#  5   product_weight_g            32951 non-null  float64
#  6   product_length_cm           32951 non-null  float64
#  7   product_height_cm           32951 non-null  float64
#  8   product_width_cm            32951 non-null  float64
#  9   product_volume_cm3          32951 non-null  float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 2.5+ MB

# %%
Product_New.isnull().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# product_volume_cm3            0
# dtype: int64

# %%
Product_New['product_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
Product_New.shape
# Out:
# (32951, 9)

# %%
Product_New['product_category_name'] = Product_New['product_category_name'].fillna('unknown')

# %%
Product_New['product_name_lenght'] = Product_New['product_name_lenght'].fillna(0)

# %%
Product_New['product_description_lenght'] = Product_New['product_description_lenght'].fillna(0)

# %%
Product_New['product_photos_qty'] = Product_New['product_photos_qty'].fillna(0)

# %%
Product_New['product_weight_g'] = Product_New['product_weight_g'].fillna(Product_New['product_weight_g'].median())

# %%
Product_New['product_length_cm'] = Product_New['product_length_cm'].fillna(Product_New['product_length_cm'].median())

# %%
Product_New['product_height_cm'] = Product_New['product_height_cm'].fillna(Product_New['product_height_cm'].median())

# %%
Product_New['product_width_cm'] = Product_New['product_width_cm'].fillna(Product_New['product_width_cm'].median())

# %%
Product_New['product_volume_cm3'] = (
    Product_New['product_length_cm'] *
    Product_New['product_height_cm'] *
    Product_New['product_width_cm']
)

# %%
Product_New['product_name_lenght'] = Product_New['product_name_lenght'].astype(int)
Product_New['product_description_lenght'] = Product_New['product_description_lenght'].astype(int)
Product_New['product_photos_qty'] = Product_New['product_photos_qty'].astype(int)

# %%
Product_New.to_csv("Product.csv",index=False)

# %%
from google.colab import files
files.download("Product.csv")

# %%
Order_Item_New.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  total_item_value
# 0 2017-09-19 09:45:00   58.90          13.29             72.19
# 1 2017-05-03 11:05:00  239.90          19.93            259.83
# ...

# %%
Order_Item_New.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# total_item_value       0
# dtype: int64

# %%
Order_Item_New['seller_id'].duplicated().sum()
# Out:
# np.int64(22376)

# %%
Order_Item_New.duplicated(subset=['order_id','order_item_id']).sum()
# Out:
# np.int64(0)

# %%
Order_Item_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24506 entries, 0 to 24505
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_id             24506 non-null  object
#  1   order_item_id        24506 non-null  int64
#  2   product_id           24506 non-null  object
#  3   seller_id            24506 non-null  object
#  4   shipping_limit_date  24506 non-null  datetime64[ns]
#  5   price                24506 non-null  float64
#  6   freight_value        24506 non-null  float64
#  7   total_item_value     24506 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 1.7+ MB

# %%
Order_Item_New[Order_Item_New.isnull().any(axis=1)]
# Out:
#                                order_id  order_item_id          product_id  \
# 24506  37d6c8f1b209eab8d1b6522a1a3e4d88              1  111d0b1e69f3496156
#
#       seller_id shipping_limit_date  price  freight_value
# 24506       NaN                 NaN    NaN            NaN

# %%
Order_Item_New = Order_Item_New.dropna()

# %%
Order_Item_New ['shipping_limit_date'] = pd.to_datetime(Order_Item_New ['shipping_limit_date'])

# %% [markdown]
# ## ## create total_item_value column

# %%
Order_Item_New['total_item_value'] = (Order_Item_New['price'] + Order_Item_New['freight_value'])

# %%
Order_Item_New.shape
# Out:
# (24506, 8)

# %%
Order_Item_New['seller_id'].str.len().unique()
# Out:
# array([32])

# %%
Order_Item_New['seller_id'] = Order_Item_New['seller_id'].str.strip()

# %%
Order_Item_New.to_csv("Order_Item.csv",index=False)

# %%
from google.colab import files
files.download("Order_Item.csv")

# %%
Order_Payments_New.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
Order_Payments_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
Order_Payments_New.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
Order_Payments_New['order_id'] = Order_Payments_New['order_id'].str.strip()

# %%
Order_Payments_New['order_id'].str.len().unique()
# Out:
# array([32])

# %%
Order_Payments_New.duplicated().sum()
# Out:
# np.int64(0)

# %%
Order_Payments_New['order_id'].duplicated().sum()
# Out:
# np.int64(4446)

# %%
Order_Payments_New['payment_type'].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# unknown            3
# Name: count, dtype: int64

# %%
Order_Payments_New['payment_type'] = Order_Payments_New['payment_type'].replace('not_defined','unknown')

# %%
Order_Payments_New.duplicated(subset=['order_id','payment_sequential']).sum()
# Out:
# np.int64(0)

# %%
Order_Payments_New.to_csv("Orders_Payments.csv",index=False)

# %%
from google.colab import files
files.download("Orders_Payments.csv")

# %%
Sellers_New.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
Sellers_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
Sellers_New['seller_id'].str.len().unique()
# Out:
# array([32])

# %%
Sellers_New['seller_id'] = Sellers_New['seller_id'].str.strip()

# %%
Sellers_New.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
Sellers_New.duplicated().sum()
# Out:
# np.int64(0)

# %%
Sellers_New['seller_city'] = Sellers_New['seller_city'].str.strip().str.lower()

# %%
Sellers_New['seller_state'] = Sellers_New['seller_state'].str.strip().str.upper()

# %%
Sellers_New['seller_state'].value_counts()
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# MS       5
# RN       5
# MT       4
# RO       2
# SE       2
# AC       1
# PI       1
# MA       1
# AM       1
# PA       1
# Name: count, dtype: int64

# %%
Sellers_New['seller_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
Sellers_New.to_csv("Sellers.csv",index=False)

# %%
from google.colab import files
files.download("Sellers.csv")

# %%
GeoLocation_New.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
GeoLocation_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19015 entries, 0 to 999846
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   geolocation_zip_code_prefix  19015 non-null  int64
#  1   geolocation_lat              19015 non-null  float64
#  2   geolocation_lng              19015 non-null  float64
#  3   geolocation_city             19015 non-null  object
#  4   geolocation_state            19015 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 891.3+ KB

# %%
GeoLocation_New.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
GeoLocation_New['geolocation_city'] = GeoLocation_New['geolocation_city'].str.strip().str.lower()

# %%
GeoLocation_New['geolocation_state'] = GeoLocation_New['geolocation_state'].str.strip().str.upper()

# %%
GeoLocation_New.duplicated().sum()
# Out:
# np.int64(0)

# %%
GeoLocation_New['geolocation_state'].duplicated().sum()
# Out:
# np.int64(18988)

# %%
GeoLocation_New = GeoLocation_New.drop_duplicates(subset = ['geolocation_zip_code_prefix'])

# %%
GeoLocation_New.to_csv("GeoLocation.csv",index=False)

# %%
from google.colab import files
files.download("GeoLocation.csv")
